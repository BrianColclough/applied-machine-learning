# %%
# import dataset from ./titanic/train.csv
import pandas as pd

train_data = pd.read_csv('./titanic/train.csv')
test_data = pd.read_csv('./titanic/test.csv')

# %%
# sanity check
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# check for missing values
print(train_data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
# show types of data for each feature
train_data.info()

train_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Looking at this, it seems that passengerID is a feature we can drop, since it’s just a unique identifier and won’t provide any discriminatory power. Ticket may be the same but I'll some testing to confirm.

# %%
# print feature names of dataframe
print(train_data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# I can build a pipeline with some custom preprocessing steps that extract a person's title, like Mr, Miss, etc. This might provide more insight and will reduce dimensionality after one-hot encoding compared to the unprocessed name field. I'm doing something similar for the deck extractor function, where we extract the cabin deck letter (A, B, C, etc.). This again reduces dimensionality after one-hot encoding while still retaining some classification power.

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import numpy as np

class TitleExtractor(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        s = X.iloc[:, 0].astype(str)
        titles = s.str.extract(r',\s*([^\.]+)\.', expand=False).str.strip()
        return titles.to_frame(name='Title')

    def get_feature_names_out(self, input_features=None):
        return np.array(['Title'])

class DeckExtractor(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        s = X.iloc[:, 0].astype(str)
        deck = s.str.extract(r'([A-Za-z])', expand=False)
        return deck.to_frame(name='Deck')

    def get_feature_names_out(self, input_features=None):
        return np.array(['Deck'])

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# Features we want to keep
numerical_features = ['Age', 'SibSp', 'Parch', 'Fare', 'Pclass']
categorical_basic = ['Sex', 'Embarked', 'Ticket']

# Pipelines
numerical_transformer = SimpleImputer(strategy='median')

categorical_basic_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

title_pipeline = Pipeline(steps=[
    ('title', TitleExtractor()),
    ('imputer', SimpleImputer(strategy='constant', fill_value='Unknown')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

deck_pipeline = Pipeline(steps=[
    ('deck', DeckExtractor()),
    ('imputer', SimpleImputer(strategy='constant', fill_value='Unknown')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat_basic', categorical_basic_transformer, categorical_basic),
        ('title', title_pipeline, ['Name']),
        ('deck', deck_pipeline, ['Cabin'])
    ],
    remainder='drop'
)

preprocessing_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor)
])

# Split X/y
y = train_data['Survived']
X = train_data.drop(columns=['Survived'])

train_data_processed = preprocessing_pipeline.fit_transform(X)

print("Preprocessing with Title and Deck created and applied successfully")
print(f"Original shape: {train_data.shape}")
print(f"Processed shape: {train_data_processed.shape}")
# Out:
# Preprocessing with Title and Deck created and applied successfully
# Original shape: (891, 12)
# Processed shape: (891, 717)

# %% [markdown]
# ### Feature Importance Scores

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
import numpy as np
import pandas as pd

def train_model(clf, X, y, seed=42, print_features=False):
    # 10-fold stratified cross-validation
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
    accuracies = cross_val_score(clf, X, y, cv=skf, scoring='accuracy')
    
    print(f"Mean accuracy: {accuracies.mean():.4f} ({chr(177)} {accuracies.std():.4f})")
    

    if print_features:
        clf.fit(X, y)
        feature_names = preprocessing_pipeline.named_steps['preprocessor'].get_feature_names_out()
        fi = pd.Series(clf.feature_importances_, index=feature_names).sort_values(ascending=False)
        
        print("\nTop features:")
        print(fi.head(25).to_string())
        print("\nLow-importance features:")
        print(fi[fi < 0.005].to_string())
    
    return accuracies

# %%
rf = RandomForestClassifier(n_estimators=300, random_state=42)
train_model(rf, train_data_processed, y, 28, True)
# Out:
# Mean accuracy: 0.8372 (± 0.0274)
#
# Top features:
# title__Title_Mr               0.084918
# num__Fare                     0.084312
# num__Age                      0.073977
# cat_basic__Sex_male           0.068822
# cat_basic__Sex_female         0.060429
# num__Pclass                   0.046163
# title__Title_Miss             0.031905
# num__SibSp                    0.030445
# title__Title_Mrs              0.026510
# deck__Deck_n                  0.024506
# num__Parch                    0.020728
# cat_basic__Embarked_C         0.010473
# cat_basic__Embarked_S         0.009969
# title__Title_Master           0.008815
# deck__Deck_E                  0.008227
# deck__Deck_B                  0.006447
# cat_basic__Ticket_1601        0.006167
# deck__Deck_D                  0.006167
# cat_basic__Embarked_Q         0.005593
# deck__Deck_C                  0.005582
# cat_basic__Ticket_65306       0.003800
# cat_basic__Ticket_350417      0.003777
# cat_basic__Ticket_350034      0.003697
# cat_basic__Ticket_A/5 3540    0.003685
# cat_basic__Ticket_312991      0.003668
#
# Low-importance features:
# cat_basic__Ticket_65306                 0.003800
# cat_basic__Ticket_350417                0.003777
# cat_basic__Ticket_350034                0.003697
# cat_basic__Ticket_A/5 3540              0.003685
# cat_basic__Ticket_312991                0.003668
# cat_basic__Ticket_367228                0.003608
# cat_basic__Ticket_350043                0.003608
# cat_basic__Ticket_2677                  0.003556
# cat_basic__Ticket_347089                0.003544
# cat_basic__Ticket_237798                0.003520
# cat_basic__Ticket_STON/O 2. 3101286     0.003503
# cat_basic__Ticket_315098                0.003498
# cat_basic__Ticket_345774                0.003495
# cat_basic__Ticket_C 17369               0.003480
# cat_basic__Ticket_244373                0.003368
# cat_basic__Ticket_244270                0.003318
# cat_basic__Ticket_345779                0.003296
# cat_basic__Ticket_A/5. 10482            0.003270
# cat_basic__Ticket_347083                0.003249
# cat_basic__Ticket_SW/PP 751             0.003231
# cat_basic__Ticket_STON/O 2. 3101289     0.003212
# cat_basic__Ticket_STON/O 2. 3101288     0.003202
# cat_basic__Ticket_STON/O 2. 3101269     0.003192
# cat_basic__Ticket_SOTON/OQ 392089       0.003175
# cat_basic__Ticket_347082                0.003136
# cat_basic__Ticket_7598                  0.003101
# cat_basic__Ticket_S.W./PP 752           0.003033
# cat_basic__Ticket_382651                0.003019
# cat_basic__Ticket_2908                  0.003001
# cat_basic__Ticket_113781                0.002944
# cat_basic__Ticket_STON/O 2. 3101285     0.002895
# cat_basic__Ticket_2678                  0.002860
# cat_basic__Ticket_349240                0.002853
# cat_basic__Ticket_347088                0.002807
# cat_basic__Ticket_2663                  0.002772
# cat_basic__Ticket_367226                0.002771
# cat_basic__Ticket_347077                0.002711
# cat_basic__Ticket_W./C. 6608            0.002689
# cat_basic__Ticket_349909                0.002516
# cat_basic__Ticket_111427                0.002494
# cat_basic__Ticket_248747                0.002464
# cat_basic__Ticket_2620                  0.002419
# cat_basic__Ticket_345773                0.002281
# cat_basic__Ticket_2691                  0.002272
# cat_basic__Ticket_237671                0.002229
# cat_basic__Ticket_SC/PARIS 2146         0.002221
# cat_basic__Ticket_382649                0.002221
# deck__Deck_A                            0.002208
# cat_basic__Ticket_113794                0.002163
# cat_basic__Ticket_A/5. 3337             0.001044
# cat_basic__Ticket_7552                  0.001029
# cat_basic__Ticket_11753                 0.001021
# cat_basic__Ticket_349245                0.001021
# cat_basic__Ticket_STON/O2. 3101282      0.001020
# cat_basic__Ticket_STON/O2. 3101283      0.001018
# cat_basic__Ticket_347080                0.001016
# cat_basic__Ticket_111369                0.001015
# cat_basic__Ticket_STON/O2. 3101271      0.001013
# cat_basic__Ticket_STON/O2. 3101290      0.001011
# cat_basic__Ticket_CA. 2314              0.000995
# cat_basic__Ticket_112277                0.000987
# cat_basic__Ticket_PC 17474              0.000977
# cat_basic__Ticket_315084                0.000964
# cat_basic__Ticket_17421                 0.000953
# cat_basic__Ticket_PC 17759              0.000941
# deck__Deck_G                            0.000929
# cat_basic__Ticket_3101281               0.000926
# cat_basic__Ticket_315096                0.000921
# cat_basic__Ticket_347085                0.000920
# cat_basic__Ticket_347073                0.000913
# cat_basic__Ticket_349236                0.000912
# cat_basic__Ticket_11967                 0.000908
# cat_basic__Ticket_4138                  0.000906
# cat_basic__Ticket_PC 17593              0.000896
# cat_basic__Ticket_PC 17475              0.000891
# cat_basic__Ticket_S.O.C. 14879          0.000868
# cat_basic__Ticket_7546                  0.000867
# cat_basic__Ticket_4135                  0.000856
# cat_basic__Ticket_343120                0.000838
# cat_basic__Ticket_248738                0.000834
# cat_basic__Ticket_345764                0.000823
# cat_basic__Ticket_250649                0.000816
# cat_basic__Ticket_3101265               0.000798
# cat_basic__Ticket_SOTON/O.Q. 392087     0.000791
# cat_basic__Ticket_350046                0.000790
# cat_basic__Ticket_13567                 0.000767
# cat_basic__Ticket_4136                  0.000762
# cat_basic__Ticket_35281                 0.000757
# cat_basic__Ticket_19950                 0.000739
# cat_basic__Ticket_347081                0.000733
# cat_basic__Ticket_2668                  0.000729
# cat_basic__Ticket_4137                  0.000725
# cat_basic__Ticket_C 7077                0.000709
# cat_basic__Ticket_345572                0.000705
# cat_basic__Ticket_11765                 0.000705
# cat_basic__Ticket_350407                0.000703
# cat_basic__Ticket_392091                0.000701
# cat_basic__Ticket_PP 9549               0.000690
# cat_basic__Ticket_13213                 0.000690
# cat_basic__Ticket_367230                0.000680
# cat_basic__Ticket_2625                  0.000671
# cat_basic__Ticket_349244                0.000666
# cat_basic__Ticket_3101278               0.000666
# title__Title_Major                      0.000664
# cat_basic__Ticket_113786                0.000659
# cat_basic__Ticket_4134                  0.000619
# cat_basic__Ticket_C.A. 2673             0.000618
# cat_basic__Ticket_W./C. 6607            0.000615
# cat_basic__Ticket_110465                0.000615
# cat_basic__Ticket_3101298               0.000600
# cat_basic__Ticket_C.A. 33112            0.000596
# cat_basic__Ticket_315153                0.000593
# cat_basic__Ticket_2650                  0.000591
# cat_basic__Ticket_13214                 0.000584
# cat_basic__Ticket_248727                0.000578
# cat_basic__Ticket_9234                  0.000567
# cat_basic__Ticket_PC 17485              0.000564
# title__Title_Sir                        0.000562
# cat_basic__Ticket_5727                  0.000561
# cat_basic__Ticket_F.C. 12750            0.000555
# cat_basic__Ticket_349219                0.000011
# cat_basic__Ticket_347078                0.000011
# cat_basic__Ticket_347468                0.000011
# cat_basic__Ticket_C.A. 29178            0.000011
# cat_basic__Ticket_350042                0.000011
# cat_basic__Ticket_350050                0.000011
# cat_basic__Ticket_11813                 0.000011
# cat_basic__Ticket_349218                0.000011
# cat_basic__Ticket_STON/O 2. 3101274     0.000011
# cat_basic__Ticket_3474                  0.000011
# cat_basic__Ticket_315082                0.000010
# cat_basic__Ticket_A/5 3536              0.000010
# cat_basic__Ticket_312992                0.000010
# cat_basic__Ticket_STON/O 2. 3101273     0.000010
# cat_basic__Ticket_233866                0.000010
# cat_basic__Ticket_347464                0.000010
# cat_basic__Ticket_SOTON/OQ 392082       0.000010
# cat_basic__Ticket_315151                0.000010
# cat_basic__Ticket_8475                  0.000010
# cat_basic__Ticket_7267                  0.000010
# cat_basic__Ticket_349221                0.000009
# cat_basic__Ticket_349215                0.000009
# cat_basic__Ticket_349224                0.000009
# cat_basic__Ticket_A/5 21173             0.000009
# cat_basic__Ticket_A/5 21174             0.000009
# cat_basic__Ticket_342826                0.000009
# cat_basic__Ticket_349910                0.000009
# cat_basic__Ticket_343276                0.000009
# cat_basic__Ticket_349208                0.000009
# cat_basic__Ticket_315094                0.000009
# cat_basic__Ticket_SOTON/O.Q. 3101306    0.000009
# cat_basic__Ticket_349227                0.000008
# cat_basic__Ticket_A/4 45380             0.000008
# cat_basic__Ticket_A/5 21172             0.000008
# cat_basic__Ticket_374887                0.000008
# cat_basic__Ticket_362316                0.000008
# cat_basic__Ticket_A/5 2466              0.000008
# cat_basic__Ticket_A./5. 2152            0.000008
# cat_basic__Ticket_349223                0.000008
# cat_basic__Ticket_A4. 54510             0.000008
# cat_basic__Ticket_392092                0.000008
# cat_basic__Ticket_347069                0.000008
# cat_basic__Ticket_349225                0.000008
# cat_basic__Ticket_SOTON/OQ 3101317      0.000008
# cat_basic__Ticket_349201                0.000008
# cat_basic__Ticket_A./5. 3235            0.000008
# cat_basic__Ticket_S.O./P.P. 751         0.000008
# cat_basic__Ticket_SOTON/OQ 392086       0.000008
# cat_basic__Ticket_349234                0.000008
# cat_basic__Ticket_315037                0.000008
# cat_basic__Ticket_C 7076                0.000008
# cat_basic__Ticket_A/4. 34244            0.000007
# cat_basic__Ticket_324669                0.000007
# cat_basic__Ticket_349207                0.000007
# cat_basic__Ticket_SOTON/OQ 3101316      0.000007
# cat_basic__Ticket_6563                  0.000007
# cat_basic__Ticket_14973                 0.000007
# cat_basic__Ticket_Fa 265302             0.000007
# cat_basic__Ticket_349222                0.000007
# cat_basic__Ticket_349217                0.000007
# cat_basic__Ticket_349203                0.000007
# cat_basic__Ticket_349248                0.000007
# cat_basic__Ticket_374746                0.000007
# cat_basic__Ticket_S.C./A.4. 23567       0.000006
# cat_basic__Ticket_A/4. 39886            0.000006
# cat_basic__Ticket_A/S 2816              0.000006
# cat_basic__Ticket_350060                0.000006
# cat_basic__Ticket_A/5 2817              0.000006
# cat_basic__Ticket_349243                0.000006
# cat_basic__Ticket_343275                0.000006
# cat_basic__Ticket_349204                0.000005
# cat_basic__Ticket_323592                0.000005
# cat_basic__Ticket_349252                0.000005
# cat_basic__Ticket_349233                0.000005
# cat_basic__Ticket_349216                0.000004
# cat_basic__Ticket_349206                0.000004
# cat_basic__Ticket_PP 4348               0.000003
# cat_basic__Ticket_345767                0.000003
# array([0.87777778, 0.86516854, 0.80898876, 0.80898876, 0.80898876,
#        0.87640449, 0.80898876, 0.85393258, 0.83146067, 0.83146067])

# %% [markdown]
# Looks like we won't be needing the ticket field, it doesn't provide much value and creates a whole lot of extra columns when we one-hot encode.
#
# Now I'm going to train the basic set of models to check the performance of each

# %%
# Features we want to keep
categorical_basic = ['Sex', 'Embarked']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat_basic', categorical_basic_transformer, categorical_basic),
        ('title', title_pipeline, ['Name']),
        ('deck', deck_pipeline, ['Cabin'])
    ],
    remainder='drop'
)

preprocessing_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor)
])

train_data_processed = preprocessing_pipeline.fit_transform(X)

rf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('rf', RandomForestClassifier(n_estimators=300, random_state=42))
])

X = train_data.drop(columns=['Survived'])
y = train_data['Survived']
train_model(rf, X, y, 28)
# Out:
# Mean accuracy: 0.8126 (± 0.0285)
# array([0.82222222, 0.84269663, 0.7752809 , 0.78651685, 0.76404494,
#        0.79775281, 0.83146067, 0.85393258, 0.83146067, 0.82022472])

# %%
# Linear SVM Classifier
from sklearn.svm import LinearSVC

svm = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('svm', LinearSVC(random_state=42))
])

X = train_data.drop(columns=['Survived'])
y = train_data['Survived']
train_model(svm, X, y, 28)
# Out:
# Mean accuracy: 0.8193 (± 0.0278)
# array([0.83333333, 0.79775281, 0.80898876, 0.80898876, 0.7752809 ,
#        0.84269663, 0.78651685, 0.86516854, 0.82022472, 0.85393258])

# %%
# RBF SVM Classifier
from sklearn.svm import SVC

rbf= Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('svm', SVC(kernel='rbf', random_state=42))
])

X = train_data.drop(columns=['Survived'])
y = train_data['Survived']
train_model(rbf, X, y, 28)
# Out:
# Mean accuracy: 0.6790 (± 0.0423)
# array([0.71111111, 0.68539326, 0.62921348, 0.69662921, 0.62921348,
#        0.75280899, 0.70786517, 0.65168539, 0.70786517, 0.61797753])

# %%
# naive bayes classifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import FunctionTransformer
nb = Pipeline(steps=[   
    ('preprocessor', preprocessor),
    # transform to array
    ('to_array', FunctionTransformer(lambda x: x.toarray())),
    ('nb', GaussianNB())
])

X = train_data.drop(columns=['Survived'])
y = train_data['Survived']
train_model(nb, X, y, 28)
# Out:
# Mean accuracy: 0.7407 (± 0.0606)
# array([0.81111111, 0.74157303, 0.76404494, 0.75280899, 0.66292135,
#        0.86516854, 0.69662921, 0.68539326, 0.75280899, 0.6741573 ])

# %%
from sklearn.linear_model import LogisticRegression
lf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('clf', LogisticRegression(solver='liblinear', max_iter=400, class_weight='balanced'))
])

X = train_data.drop(columns=['Survived'])
y = train_data['Survived']
train_model(lf, X, y, 28)
# Out:
# Mean accuracy: 0.8159 (± 0.0304)
# array([0.84444444, 0.7752809 , 0.78651685, 0.78651685, 0.80898876,
#        0.86516854, 0.78651685, 0.82022472, 0.83146067, 0.85393258])

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

y = train_data['Survived']
X = train_data.drop(columns=['Survived'])

# Train/validation split for final evaluation
X_tr, X_te, y_tr, y_te = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

rf_pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('clf', RandomForestClassifier(random_state=42, n_jobs=-1))
])

# Hyperparameter search grid 
param_grid = {
    'clf__n_estimators': [200, 400, 800],
    'clf__max_depth': [None, 8, 12, 20],
    'clf__min_samples_split': [2, 5, 10],
    'clf__min_samples_leaf': [1, 2, 4],
    'clf__max_features': ['sqrt', 'log2', None],
    'clf__class_weight': [None, 'balanced'],
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

gs = GridSearchCV(
    estimator=rf_pipe,
    param_grid=param_grid,
    scoring={'roc_auc': 'roc_auc', 'accuracy': 'accuracy', 'f1': 'f1'},
    refit='roc_auc',
    cv=cv,
    n_jobs=-1,
    verbose=1,
)

gs.fit(X_tr, y_tr)

print("Best params:", gs.best_params_)
print("Best CV ROC-AUC:", gs.best_score_)

# Evaluate on test data
y_pred = gs.predict(X_te)
y_proba = gs.predict_proba(X_te)[:, 1]
print("Hold-out ROC-AUC:", roc_auc_score(y_te, y_proba))
print("Classification report:\n", classification_report(y_te, y_pred, digits=4))
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# Best params: {'clf__class_weight': 'balanced', 'clf__max_depth': 20, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 5, 'clf__n_estimators': 800}
# Best CV ROC-AUC: 0.8835273714153024
# Hold-out ROC-AUC: 0.8477602108036891
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.8393    0.8545    0.8468       110
#            1     0.7612    0.7391    0.7500        69
#
#     accuracy                         0.8101       179
#    macro avg     0.8002    0.7968    0.7984       179
# weighted avg     0.8092    0.8101    0.8095       179

# %%
# tain a model using the best parameters
X = train_data.drop(columns=['Survived'])
y = train_data['Survived']

best_model = Pipeline(steps=[   
    ('preprocessor', preprocessor),
    ('clf', RandomForestClassifier(random_state=42, n_jobs=-1, class_weight='balanced', max_depth=20, max_features='sqrt', min_samples_split=5, min_samples_leaf=2, n_estimators=800))
])

train_model(best_model, X, y, 28)
# Out:
# Mean accuracy: 0.8339 (± 0.0257)
# array([0.85555556, 0.83146067, 0.80898876, 0.82022472, 0.83146067,
#        0.88764045, 0.79775281, 0.85393258, 0.84269663, 0.80898876])

# %%
# use the best model to predict the test set
best_model.fit(X, y)
y_pred = best_model.predict(test_data)

def save_preds(_fn, _y_pred, _df):
    import csv
    with open(_fn, 'w') as fout:
        writer = csv.writer(fout, delimiter=',', lineterminator='\n')
        writer.writerow(['PassengerId', 'Survived'])
        for yid, ypred in zip(_df['PassengerId'], _y_pred):
            writer.writerow([yid, ypred])

save_preds('predictions_colclough.csv', y_pred, test_data)

# %% [markdown]
# I was able to make my first submission on kaggle using this the output here. This was a really fun assignment! I decided to go with the random forrest classifier as it and the linear svm were very close in score, but I know how robust random forrest classifiers can be. In the assignment instructions had also mentioned using a random forest and getting a 79% score, which I thought would be a good benchmark for my classifier. My classifier was able to acheive a score of 75.3% when I uploded my results to Kaggle
#
# ![Alt text](./score.png)
